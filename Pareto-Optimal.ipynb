# %%
import benders
import datetime

# %%
# Customer number
n = 400
# Facility candidates
m = 20
# Instance save to local file name
fileName = "test.dat"
# Generate instance
instance = benders.generateInstance(n, m, fileName)

# %%
# Read instance from local file (easier to repeat)
instance = benders.readInstance(fileName)

# %%
# Directly use gruobi, which is extremely fast
# This is not for comparison, gurobi are using some high-level techniques
# This is for validating the optimal solution
benders.directSolveProblem(instance)
# Out:
# Academic license - for non-commercial use only
# Optimize a model with 8400 rows, 8020 columns and 24000 nonzeros
# Variable types: 8000 continuous, 20 integer (20 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [5e+01, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 83639.000000
# Presolve time: 0.02s
# Presolved: 8400 rows, 8020 columns, 24000 nonzeros
# Variable types: 8000 continuous, 20 integer (20 binary)
#
# Root relaxation: objective 3.476715e+04, 2701 iterations, 0.11 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 34767.1463    0   15 83639.0000 34767.1463  58.4%     -    0s
# H    0     0                    50650.975610 34767.1463  31.4%     -    0s
# H    0     0                    43340.000000 34767.1463  19.8%     -    0s
#      0     0 34771.1768    0   16 43340.0000 34771.1768  19.8%     -    0s
#      0     0 34773.6650    0   16 43340.0000 34773.6650  19.8%     -    0s
#      0     0 34774.4899    0   16 43340.0000 34774.4899  19.8%     -    0s
#      0     0 34774.5426    0   16 43340.0000 34774.5426  19.8%     -    0s
#      0     0 34779.6693    0   16 43340.0000 34779.6693  19.8%     -    0s
#      0     0 34780.5764    0   16 43340.0000 34780.5764  19.7%     -    0s
#      0     0 34780.7233    0   16 43340.0000 34780.7233  19.7%     -    0s
#      0     0 34780.7263    0   17 43340.0000 34780.7263  19.7%     -    0s
#      0     0 34783.1763    0   17 43340.0000 34783.1763  19.7%     -    0s
#      0     0 34785.7749    0   18 43340.0000 34785.7749  19.7%     -    0s
#      0     0 34785.7749    0   18 43340.0000 34785.7749  19.7%     -    0s
# H    0     0                    42619.000000 34785.7749  18.4%     -    0s
# H    0     0                    37606.000000 34785.7749  7.50%     -    0s
#      0     2 34785.7749    0   18 37606.0000 34785.7749  7.50%     -    0s
# *   24    24               4    35978.000000 35258.0930  2.00%   380    1s
# *   26    22               5    35799.000000 35258.0930  1.51%   369    1s
# *   35    11               5    35714.000000 35258.0930  1.28%   311    1s
#
# Cutting planes:
#   Gomory: 8
#
# Explored 51 nodes (15375 simplex iterations) in 1.60 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 8: 35714 35799 35978 ... 83639
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.571400000000e+04, best bound 3.571400000000e+04, gap 0.0000%
# {'ofv': 35714.0, 'y': [3, 11, 13, 16, 17, 19]}

# %%
# Use Pareto-optimal cuts to accelerate
start = datetime.datetime.now()
res = benders.masterProblem(instance, True)
t = (datetime.datetime.now() - start).total_seconds()
print(res)
print("Total time: ", t)
# Out:
# Changed value of parameter lazyConstraints to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Add feasibility cut
# Add feasibility cut
# Add feasibility cut
# Add feasibility cut
# Add feasibility cut
# Add feasibility cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# {'ofv': 35714.0, 'y': [3, 11, 13, 16, 17, 19]}
# Total time:  155.38073

# %%
# Not using Pareto-optimal cuts
start = datetime.datetime.now()
res = benders.masterProblem(instance, False)
t = (datetime.datetime.now() - start).total_seconds()
print(res)
print("Total time: ", t)
# Out:
# Changed value of parameter lazyConstraints to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Add feasibility cut
# Add feasibility cut
# Add feasibility cut
# Add feasibility cut
# Add feasibility cut
# Add feasibility cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# {'ofv': 35714.000000000015, 'y': [3, 11, 13, 16, 17, 19]}
# Total time:  192.948028
